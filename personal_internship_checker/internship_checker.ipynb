# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time
import csv

# Email Configuration
EMAIL_ADDRESS = 'andrew.patella04@gmail.com'
EMAIL_PASSWORD = 'kzxx ydkk iksd qcvs'


# Load URLs from Excel
def load_urls(file_path):
    df = pd.read_excel(file_path)
    return df[['Company', 'URL']].values.tolist()

# Allowing for mitigation of companies


# Check URLs for Keywords
def check_internships(urls, keywords):
    found_companies = []

    for company, url in urls:
        try:
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')
                text = soup.get_text().lower()

                # Extract and process links/buttons correctly
                links = [a.get_text().strip().lower() for a in soup.find_all('a', href=True) if a.get_text()]
                buttons = [btn.get_text().strip().lower() for btn in soup.find_all(['button', 'input']) if
                           btn.get_text()]

                # Check keywords in links and buttons (correctly handling lists)
                for keyword in keywords:
                    if any(keyword.lower() in link for link in links) or \
                            any(keyword.lower() in button for button in buttons):
                        found_companies.append((company, url))
                        break  # Avoid adding duplicates if multiple matches are found
        except Exception as e:
            print(f"Error accessing {url}: {e}")

    return found_companies

# Send Email Notification
def send_email(companies):
    if companies:
        subject = 'Internship Opportunities Found'
        body = "The following companies have internship listings or mentions:\n\n"
        body += "\n".join([f" - {company} has internships available: {url}" for company, url in companies])
        body += "\n\n Happy hunting!"
    else:
        subject = 'No Internships Found'
        body = "No internship listings or mentions were found today."

    msg = MIMEMultipart()
    msg['From'] = EMAIL_ADDRESS
    msg['To'] = 'andrew.patella04@gmail.com'
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))  # Send as plain text for simplicity

    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
        server.send_message(msg)


# Main Job to Run Daily
def job():
    urls = load_urls(r"C:/Users/ajpat/OneDrive/Documents/GitHub/Portfolio/personal_internship_checker/companies_urls.xlsx")
    keywords = ['scientist','intern', 'internship', 'summer intern', 'summer 2026','GNC','Guidance','navigation','control','automation','astrodynamics','orbit','master']
    found_companies = check_internships(urls, keywords)
    send_email(found_companies)
    print("Internships compiled. Happy hunting!")


# Run Immediately for Testing
job()

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time
import csv

# Email Configuration
EMAIL_ADDRESS = 'andrew.patella04@gmail.com'
EMAIL_PASSWORD = 'kzxx ydkk iksd qcvs'


# Load URLs from Excel
def load_urls(file_path):
    df = pd.read_excel(file_path)
    return df[['Company', 'URL']].values.tolist()

# Allowing for mitigation of companies

def check_internships(urls, keywords):
    found_positions = []

    for company, url in urls:
        try:
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')

                # Candidate tags where job titles usually appear
                possible_tags = soup.find_all(['a', 'h2', 'h3', 'li', 'div', 'span'])
                positions = []

                for tag in possible_tags:
                    text = tag.get_text().strip()
                    if any(keyword.lower() in text.lower() for keyword in keywords):
                        positions.append(text)

                if positions:  # if we found matches
                    found_positions.append((company, url, positions))

        except Exception as e:
            print(f"Error accessing {url}: {e}")

    return found_positions

# Send Email Notification
def send_email(companies):
    if companies:
        subject = 'Opportunities Found'
        body = "The following companies have job listings matching your keywords:\n\n"
        for company, url, positions in companies:
            body += f"- {company} ({url}):\n"
            for pos in positions:
                body += f"   * {pos}\n"
            body += "\n"
        body += "\nHappy hunting!"
    else:
        subject = 'No Opportunities Found'
        body = "No listings matching your keywords were found today."

    msg = MIMEMultipart()
    msg['From'] = EMAIL_ADDRESS
    msg['To'] = 'andrew.patella04@gmail.com'
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))

    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
        server.send_message(msg)



# Main Job to Run Daily
def job():
    urls = load_urls(r"C:/Users/ajpat/OneDrive/Documents/GitHub/Portfolio/personal_internship_checker/co_gnc_companies.xlsx")
    keywords = ['intern', 'internship', 'summer intern', 'summer 2026','GNC','Guidance','navigation','control','automation','astrodynamics','orbit','master']
    found_companies = check_internships(urls, keywords)
    send_email(found_companies)
    print("Internships compiled. Happy hunting!")


# Run Immediately for Testing
job()

# %%
import sys
# !{sys.executable} -m pip install webdriver_manager

# %%
from functions import *



def parse_generic(url, company_name="Unknown", use_selenium_fallback=True, max_wait=8):
    """
    New parse_generic:
    - Collects all <a> and <button> elements (potential jobs).
    - Gathers surrounding text and attributes.
    - Filters out banners/menus, keeps only items with job-like signals.
    - Returns list of dicts {company, title, link, extras}.
    """

    jobs = []
    seen_links = set()

    # Whitelist/blacklist terms
    WHITELIST = {"apply", "job", "career", "opening", "opportunity", "position", "engineer", "internship"}
    BLACKLIST = {"about", "login", "register", "privacy", "terms", "news", "press", "banner", "menu", "policy","company"}

    def is_joblike(text):
        t = text.lower()
        return any(w in t for w in WHITELIST) and not any(b in t for b in BLACKLIST)

    try:
        response = requests.get(url, timeout=12, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
    except Exception as e:
        print(f"[Requests failed for {company_name}] {e}")
        soup = None

    candidates = []

    if soup:
        # Collect all anchors and buttons
        elems = soup.find_all(["a", "button"])
        for el in elems:
            text = el.get_text(" ", strip=True)
            link = el.get("href") or el.get("onclick")

            # collect nearby info (parent text snippet)
            parent_text = ""
            if el.parent:
                parent_text = el.parent.get_text(" ", strip=True)

            # merge text info
            combined_text = " ".join({text, parent_text}).strip()

            candidates.append({
                "element": el.name,
                "text": text,
                "combined_text": combined_text,
                "attrs": dict(el.attrs),
                "link": link
            })

        # Filter candidates
        for c in candidates:
            if not c["combined_text"]:
                continue
            if not is_joblike(c["combined_text"]):
                continue
            if not c["link"]:
                continue

            link = urljoin(url, c["link"])
            if link in seen_links:
                continue

            jobs.append({
                "company": company_name,
                "title": c["text"] or c["combined_text"][:80],
                "link": link,
                "extras": {
                    "combined_text": c["combined_text"],
                    "attrs": c["attrs"]
                }
            })
            seen_links.add(link)

    # Selenium fallback if nothing found
    if not jobs and use_selenium_fallback:
        try:
            print(f"[Selenium fallback for {company_name}]")
            options = webdriver.ChromeOptions()
            options.add_argument("--headless=new")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
            driver.get(url)
            time.sleep(max_wait)

            elems = driver.find_elements(By.XPATH, "//a | //button")
            for el in elems:
                text = el.text.strip()
                link = el.get_attribute("href") or el.get_attribute("onclick")
                parent_text = ""
                try:
                    parent = el.find_element(By.XPATH, "..")
                    parent_text = parent.text.strip()
                except Exception:
                    pass

                combined_text = " ".join({text, parent_text}).strip()

                if not is_joblike(combined_text):
                    continue
                if not link:
                    continue

                link = urljoin(url, link)
                if link in seen_links:
                    continue

                jobs.append({
                    "company": company_name,
                    "title": text or combined_text[:80],
                    "link": link,
                    "extras": {"combined_text": combined_text}
                })
                seen_links.add(link)

            driver.quit()
        except Exception as e:
            print(f"[Selenium failed for {company_name}] {e}")

    return jobs



def parse_rbox(url, company_name="Unknown"):
    """Parser for Recruiterbox-style career pages (div.rbox-opening-li)."""
    jobs = []
    seen = set()

    try:
        response = requests.get(url, timeout=12, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")

        for li in soup.select("div.rbox-opening-li"):
            a = li.find("a", href=True)
            if not a:
                continue
            title = a.get_text(strip=True)
            link = urljoin(url, a["href"])

            if not title or link in seen:
                continue

            jobs.append({
                "company": company_name,
                "title": title,
                "link": link
            })
            seen.add(link)
    except Exception as e:
        print(f"[RBox failed for {company_name}] {e}")

    

    return jobs


def parse_edge_case(url, company, keywords):
    """
    Super-general parser for sites where parse_generic fails.
    It:
    - Scans all links and buttons.
    - Collects surrounding context (parent/sibling text).
    - Filters for job-related items.
    - Filters again by keywords.
    """

    job_like_words = ["apply", "career", "job", "opportunit", "opening", "position", "vacancy", "work with us"]

    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
    except Exception as e:
        print(f"[ERROR] Could not fetch {url}: {e}")
        return []

    soup = BeautifulSoup(r.text, "html.parser")
    results = []

    for tag in soup.find_all(["a", "button"]):
        text = (tag.get_text(strip=True) or "").lower()
        href = tag.get("href")
        if not text and not href:
            continue

        link = urljoin(url, href) if href else url

        # Gather context around the tag
        context_text = " ".join(
            [t.get_text(strip=True) for t in tag.find_parents(limit=2)]
        ).lower()

        # Merge button text + context
        combined_text = (text + " " + context_text).strip()

        extras = {attr: tag.get(attr) for attr in tag.attrs if attr not in ["href"]}

        results.append({
            "company": company,
            "title": combined_text[:200],  # keep it short-ish
            "link": link,
            "extras": extras,
        })

    # Step 1: filter for anything job-like
    job_candidates = [r for r in results if any(w in r["title"] for w in job_like_words)]

    # Step 2: filter by keywords
    final_jobs = []
    for job in job_candidates:
        title = job["title"].lower()
        if any(kw.lower() in title for kw in keywords):
            final_jobs.append(job)

    return final_jobs

#########################################################################################
#########################################################################################
#########################################################################################
def scrape_jobs(company, url):
    if "greenhouse.io" in url:
        return parse_greenhouse(url)
    elif "lever.co" in url:
        return parse_lever(url)
    elif "myworkdayjobs.com" in url:
        # Use generic + Selenium fallback for Workday too
        return parse_generic(url, company_name=company)
    elif "rbox" in url or "recruiterbox" in url:
        return parse_rbox(url, company_name=company)
    else:
        jobs = parse_generic(url, company, keywords)
        
        return jobs


def run(csv_file, keywords, email_config=None):
    companies = load_companies(csv_file)
    seen = load_seen()
    new_seen = set(seen)
    new_jobs = {}

    for _, row in companies.iterrows():
        company, url = row["company"], row["url"]
        try:
            jobs = scrape_jobs(company, url)
            jobs = filter_jobs(jobs, keywords)
            if not jobs:  # fallback
                jobs = parse_edge_case(url, company, keywords)
                jobs = filter_jobs(jobs, keywords)
            fresh = [j for j in jobs if j["link"] not in seen]
            if fresh:
                new_jobs[company] = fresh
                for j in fresh:
                    new_seen.add(j["link"])
        except Exception as e:
            print(f"Error scraping {company}: {e}")

    save_seen(new_seen)

    if email_config and new_jobs:
        send_email(new_jobs, **email_config)

    return new_jobs
keywords = ["intern", "gnc", "satellite", "orbit","guidance","navigation","control","operations","simulation"]
email_config = {
    "recipient": "andrew.patella04@gmail.com",
    "sender": "andrew.patella04@gmail.com",
    "password": "kzxx ydkk iksd qcvs"
}
run("companies.csv", keywords, email_config)
# Out:
# [Requests failed for Blue Origin] HTTPSConnectionPool(host='www.blueorigin.com', port=443): Read timed out. (read timeout=12)
# [Selenium fallback for Blue Origin]
# ...

# %%
def parse_generic(url, company_name="Unknown", use_selenium_fallback=True, max_wait=8):
    """
    Robust generic parser:
    - Returns list of dicts: {"company", "title", "link"}
    - Handles anchor-as-card, fallbacks, JSON-LD JobPosting, and filters generic headings.
    """
    jobs = []
    seen_links = set()

    # Expand your patterns (added Blue Canyon / Kadence / BambooHR and alternative card selectors)
    patterns = [
        # Workday
        {"card": "div.JobListing_jobListItems__1xfbo, div.JobListing_jobListItems__1xfbo > div", 
        "title": "p.JobListing_jobTitle__t_LIY, .JobListing_jobTitle__t_LIY", 
        "link": "a[href]"},
        # A broader wrapper option (if individual items are nested differently)
        {"card": "div.JobListing_jobsContentWrapper__k1obW, div.JobListing_jobListContent__Pc98R", 
        "title": "p.JobListing_jobTitle__t_LIY", 
        "link": "a[href]"},
        {"card": "li.css-1q2dra3", "title": "a", "link": "a"},
        {"card": "li[data-automation-id='compositeTile']", "title": "div[data-automation-id='jobTitle']", "link": "a"},
        {"card": "div[data-automation-id='jobPosting']", "title": "div[data-automation-id='jobTitle']", "link": "a"},

        # BambooHR / Kadence (Blue Canyon)
        {"card": "a.kb-advanced-heading-link", "title": "div.wp-block-kadence-advancedheading", "link": "a"},
        {"card": "div.kt-inside-inner-col", "title": "a.kb-advanced-heading-link div.wp-block-kadence-advancedheading", "link": "a.kb-advanced-heading-link"},

        # Greenhouse
        {"card": "div.opening", "title": "a", "link": "a"},

        # Lever
        {"card": "div.posting", "title": "h5", "link": "a"},
        {"card": "section.posting", "title": "h5", "link": "a"},

        # SmartRecruiters
        {"card": "li.list-group-item", "title": "h4.title", "link": "a"},
        {"card": "div.opening-job", "title": "h4", "link": "a"},

        # Taleo / Oracle
        {"card": "tr[id^='jobs']", "title": "span.titlelink", "link": "a"},
        {"card": "table[id*='jobs'] tr", "title": "a", "link": "a"},

        # iCIMS / Jobvite / Ashby fallbacks
        {"card": "div.iCIMS_Expandable_Container", "title": "a", "link": "a"},
        {"card": "div.row.job", "title": "a", "link": "a"},
        {"card": "div.jv-job-list", "title": "h4", "link": "a"},
        {"card": "li.Ashby-JobPosting", "title": "a", "link": "a"},

        # Generic catch-alls
        {"card": "a.job-card", "title": ".job-card__title", "link": "a"},
        {"card": "li", "title": "h3", "link": "a"},
        {"card": "div", "title": "h2", "link": "a"}
    ]

    # blacklist for obvious non-job headings
    BLACKLIST_TITLES = {"careers", "career", "open positions", "job openings", "current openings", "positions", "jobs"}

    try:
        response = requests.get(url, timeout=12, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
    except Exception as e:
        print(f"[Requests failed for {company_name}] {e}")
        soup = None

    # --- Try JSON-LD JobPosting first (often present on career pages) ---
    if soup:
        try:
            for script in soup.find_all("script", type="application/ld+json"):
                try:
                    js = json.loads(script.string or "{}")
                except Exception:
                    continue
                def extract_job_from_obj(obj):
                    if not obj: return
                    # if it's an array
                    if isinstance(obj, list):
                        for o in obj:
                            extract_job_from_obj(o)
                        return
                    # JobPosting
                    if obj.get("@type") == "JobPosting" or "JobPosting" in obj.get("@type", ""):
                        title = obj.get("title") or obj.get("name")
                        link = obj.get("url") or obj.get("identifier", {}).get("value")
                        if title and link:
                            link = urljoin(url, link)
                            if link not in seen_links and title.lower().strip() not in BLACKLIST_TITLES:
                                jobs.append({"company": company_name, "title": title.strip(), "link": link})
                                seen_links.add(link)
                extract_job_from_obj(js)
        except Exception:
            pass

    # --- Try pattern matching on rendered HTML ---
    if soup:
        for pat in patterns:
            try:
                job_cards = soup.select(pat["card"])
            except Exception:
                job_cards = []
            if not job_cards:
                continue

            for card in job_cards:
                # Title resolution
                title_elem = None
                if "title" in pat and pat["title"]:
                    try:
                        title_elem = card.select_one(pat["title"])
                    except Exception:
                        title_elem = None

                # fallback searching common tags inside card
                if not title_elem:
                    for tag in ("h1","h2","h3","h4","h5","a","span","div"):
                        try:
                            el = card.select_one(tag)
                        except Exception:
                            el = None
                        if el and el.get_text(strip=True):
                            title_elem = el
                            break

                # Link resolution
                link = None
                # If the card itself is an anchor, use it
                try:
                    if getattr(card, "name", "").lower() == "a" and card.has_attr("href"):
                        link = card["href"]
                except Exception:
                    pass

                # else use specified link selector inside the card
                if not link:
                    if "link" in pat and pat["link"]:
                        try:
                            link_elem = card.select_one(pat["link"])
                        except Exception:
                            link_elem = None
                        if link_elem and link_elem.has_attr("href"):
                            link = link_elem["href"]

                # as a last resort find any anchor inside the card
                if not link:
                    a = card.find('a', href=True)
                    if a:
                        link = a['href']

                if not title_elem or not link:
                    continue

                title_text = title_elem.get_text(strip=True)
                if not title_text:
                    continue

                # skip generic non-job headings
                if title_text.lower().strip() in BLACKLIST_TITLES:
                    continue

                link = urljoin(url, link)

                if link in seen_links:
                    continue

                jobs.append({"company": company_name, "title": title_text, "link": link})
                seen_links.add(link)

            if jobs:
                # found some jobs for this pattern -> return them (keeps behavior similar to original)
                return jobs

    # --- Selenium fallback (if nothing found and allowed) ---
    if use_selenium_fallback:
        try:
            print(f"[Selenium fallback for {company_name}]")
            options = webdriver.ChromeOptions()
            options.add_argument("--headless=new")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
            driver.get(url)
            time.sleep(max_wait)

            for pat in patterns:
                try:
                    els = driver.find_elements(By.CSS_SELECTOR, pat["card"])
                except Exception:
                    els = []
                if not els:
                    continue

                for el in els:
                    try:
                        # get title
                        title_text = ""
                        if pat.get("title"):
                            try:
                                t = el.find_element(By.CSS_SELECTOR, pat["title"])
                                title_text = t.text.strip()
                            except Exception:
                                pass
                        if not title_text:
                            # fallback common tags
                            for sel in ("h1","h2","h3","h4","h5","a","span","div"):
                                try:
                                    t = el.find_element(By.CSS_SELECTOR, sel)
                                    if t and t.text.strip():
                                        title_text = t.text.strip()
                                        break
                                except Exception:
                                    pass

                        # get link
                        link = None
                        try:
                            if el.tag_name.lower() == "a":
                                link = el.get_attribute("href")
                        except Exception:
                            pass
                        if not link and pat.get("link"):
                            try:
                                l = el.find_element(By.CSS_SELECTOR, pat["link"])
                                link = l.get_attribute("href")
                            except Exception:
                                pass
                        if not link:
                            try:
                                l = el.find_element(By.CSS_SELECTOR, "a[href]")
                                link = l.get_attribute("href")
                            except Exception:
                                pass

                        if not title_text or not link:
                            continue
                        if title_text.lower().strip() in BLACKLIST_TITLES:
                            continue

                        link = urljoin(url, link)
                        if link in seen_links:
                            continue

                        jobs.append({"company": company_name, "title": title_text, "link": link})
                        seen_links.add(link)
                    except Exception:
                        continue

                if jobs:
                    break

            driver.quit()
        except Exception as e:
            print(f"[Selenium failed for {company_name}] {e}")

    return jobs

parse_generic()
