# %%
from functions import *



def parse_generic(url, company_name="Unknown", use_selenium_fallback=True, max_wait=8):
    """
    New parse_generic:
    - Collects all <a> and <button> elements (potential jobs).
    - Gathers surrounding text and attributes.
    - Filters out banners/menus, keeps only items with job-like signals.
    - Returns list of dicts {company, title, link, extras}.
    """

    jobs = []
    seen_links = set()

    # Whitelist/blacklist terms
    WHITELIST = {"apply", "job", "career", "opening", "opportunity", "position", "engineer", "internship"}
    BLACKLIST = {"about", "login", "register", "privacy", "terms", "news", "press", "banner", "menu", "policy","company"}

    def is_joblike(text):
        t = text.lower()
        return any(w in t for w in WHITELIST) and not any(b in t for b in BLACKLIST)

    try:
        response = requests.get(url, timeout=12, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
    except Exception as e:
        print(f"[Requests failed for {company_name}] {e}")
        soup = None

    candidates = []

    if soup:
        # Collect all anchors and buttons
        elems = soup.find_all(["a", "button"])
        for el in elems:
            text = el.get_text(" ", strip=True)
            link = el.get("href") or el.get("onclick")

            # collect nearby info (parent text snippet)
            parent_text = ""
            if el.parent:
                parent_text = el.parent.get_text(" ", strip=True)

            # merge text info
            combined_text = " ".join({text, parent_text}).strip()

            candidates.append({
                "element": el.name,
                "text": text,
                "combined_text": combined_text,
                "attrs": dict(el.attrs),
                "link": link
            })

        # Filter candidates
        for c in candidates:
            if not c["combined_text"]:
                continue
            if not is_joblike(c["combined_text"]):
                continue
            if not c["link"]:
                continue

            link = urljoin(url, c["link"])
            if link in seen_links:
                continue

            jobs.append({
                "company": company_name,
                "title": c["text"] or c["combined_text"][:80],
                "link": link,
                "extras": {
                    "combined_text": c["combined_text"],
                    "attrs": c["attrs"]
                }
            })
            seen_links.add(link)

    # Selenium fallback if nothing found
    if not jobs and use_selenium_fallback:
        try:
            print(f"[Selenium fallback for {company_name}]")
            options = webdriver.ChromeOptions()
            options.add_argument("--headless=new")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
            driver.get(url)
            time.sleep(max_wait)

            elems = driver.find_elements(By.XPATH, "//a | //button")
            for el in elems:
                text = el.text.strip()
                link = el.get_attribute("href") or el.get_attribute("onclick")
                parent_text = ""
                try:
                    parent = el.find_element(By.XPATH, "..")
                    parent_text = parent.text.strip()
                except Exception:
                    pass

                combined_text = " ".join({text, parent_text}).strip()

                if not is_joblike(combined_text):
                    continue
                if not link:
                    continue

                link = urljoin(url, link)
                if link in seen_links:
                    continue

                jobs.append({
                    "company": company_name,
                    "title": text or combined_text[:80],
                    "link": link,
                    "extras": {"combined_text": combined_text}
                })
                seen_links.add(link)

            driver.quit()
        except Exception as e:
            print(f"[Selenium failed for {company_name}] {e}")

    return jobs



def parse_rbox(url, company_name="Unknown"):
    """Parser for Recruiterbox-style career pages (div.rbox-opening-li)."""
    jobs = []
    seen = set()

    try:
        response = requests.get(url, timeout=12, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")

        for li in soup.select("div.rbox-opening-li"):
            a = li.find("a", href=True)
            if not a:
                continue
            title = a.get_text(strip=True)
            link = urljoin(url, a["href"])

            if not title or link in seen:
                continue

            jobs.append({
                "company": company_name,
                "title": title,
                "link": link
            })
            seen.add(link)
    except Exception as e:
        print(f"[RBox failed for {company_name}] {e}")

    

    return jobs


def parse_edge_case(url, company, keywords):
    """
    Super-general parser for sites where parse_generic fails.
    It:
    - Scans all links and buttons.
    - Collects surrounding context (parent/sibling text).
    - Filters for job-related items.
    - Filters again by keywords.
    """

    job_like_words = ["apply", "career", "job", "opportunit", "opening", "position", "vacancy", "work with us"]

    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
    except Exception as e:
        print(f"[ERROR] Could not fetch {url}: {e}")
        return []

    soup = BeautifulSoup(r.text, "html.parser")
    results = []

    for tag in soup.find_all(["a", "button"]):
        text = (tag.get_text(strip=True) or "").lower()
        href = tag.get("href")
        if not text and not href:
            continue

        link = urljoin(url, href) if href else url

        # Gather context around the tag
        context_text = " ".join(
            [t.get_text(strip=True) for t in tag.find_parents(limit=2)]
        ).lower()

        # Merge button text + context
        combined_text = (text + " " + context_text).strip()

        extras = {attr: tag.get(attr) for attr in tag.attrs if attr not in ["href"]}

        results.append({
            "company": company,
            "title": combined_text[:200],  # keep it short-ish
            "link": link,
            "extras": extras,
        })

    # Step 1: filter for anything job-like
    job_candidates = [r for r in results if any(w in r["title"] for w in job_like_words)]

    # Step 2: filter by keywords
    final_jobs = []
    for job in job_candidates:
        title = job["title"].lower()
        if any(kw.lower() in title for kw in keywords):
            final_jobs.append(job)

    return final_jobs

#########################################################################################
#########################################################################################
#########################################################################################
def scrape_jobs(company, url):
    if "greenhouse.io" in url:
        return parse_greenhouse(url)
    elif "lever.co" in url:
        return parse_lever(url)
    elif "myworkdayjobs.com" in url:
        # Use generic + Selenium fallback for Workday too
        return parse_generic(url, company_name=company)
    elif "rbox" in url or "recruiterbox" in url:
        return parse_rbox(url, company_name=company)
    else:
        jobs = parse_generic(url, company, keywords)
        
        return jobs


def run(csv_file, keywords, email_config=None):
    companies = load_companies(csv_file)
    seen = load_seen()
    new_seen = set(seen)
    new_jobs = {}

    for _, row in companies.iterrows():
        company, url = row["company"], row["url"]
        try:
            jobs = scrape_jobs(company, url)
            jobs = filter_jobs(jobs, keywords)
            if not jobs:  # fallback
                jobs = parse_edge_case(url, company, keywords)
                jobs = filter_jobs(jobs, keywords)
            fresh = [j for j in jobs if j["link"] not in seen]
            if fresh:
                new_jobs[company] = fresh
                for j in fresh:
                    new_seen.add(j["link"])
        except Exception as e:
            print(f"Error scraping {company}: {e}")

    save_seen(new_seen)

    if email_config and new_jobs:
        send_email(new_jobs, **email_config)

    return new_jobs
keywords = ["intern", "gnc", "satellite", "orbit","guidance","navigation","control","operations","simulation"]
email_config = {
    "recipient": "andrew.patella04@gmail.com",
    "sender": "andrew.patella04@gmail.com",
    "password": "kzxx ydkk iksd qcvs"
}
run("companies.csv", keywords, email_config)
