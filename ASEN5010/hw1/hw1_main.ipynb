# %%
import numpy as np
from attitude_package.dcms import *

x = vector(0,1,2,'ROW')
print(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 from attitude_package.dcms import *
#       4 x = vector(0,1,2,'ROW')
#       5 print(x)
#
# ModuleNotFoundError: No module named 'attitude_package'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\ajpat\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe
