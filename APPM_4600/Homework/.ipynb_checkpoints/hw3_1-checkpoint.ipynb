# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt


def driver():
    # Question 1 =====================================================================
    f = lambda x: 2*x-np.sin(x) - 1
    a = 0
    b = np.pi

    tol = 1e-8

    [astar, ier] = bisection(f, a, b, tol)
    print('the approximate root is', astar)
    print('the error message reads:', ier)
    print('f(astar) =', f(astar))

    # Question 2 =====================================================================
    f = lambda x: (x-5)**9
    a = 4.82
    b = 5.2
    tol = 1e-4

    print("PROBLEM 2a ==========================================")
    [astar, ier] = bisection(f, a, b, tol)
    print('the approximate root is', astar)
    print('f(astar) =', f(astar))

    f = lambda x: (x**9 - 45*x**8 + 900*x**7 - 10500*x**6 +
            78750*x**5 - 393750*x**4 + 1312500*x**3 -
            2812500*x**2 + 3515625*x - 1953125)

    print("PROBLEM 2b ==========================================")
    [astar, ier] = bisection(f, a, b, tol)
    print('the approximate root is', astar)
    print('f(astar) =', f(astar))

    # Question 3 =====================================================================
    f = lambda x: x**3 + x - 4
    a = 1
    b = 4
    tol = 1e-3

    print("PROBLEM 3  ==========================================")
    [astar, ier] = bisection(f, a, b, tol)
    print('the approximate root is', astar)
    print('f(astar) =', f(astar))

    # Question 4 =====================================================================

    # Question 5  =====================================================================
    x = np.linspace(-5,10,100)
    y = x - 4*np.sin(2*x)-3
    yaxis = np.zeros((100,1))

    plt.figure()
    plt.plot(x,yaxis)
    plt.plot(x,y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid()

# define routines
def bisection(f, a, b, tol):

    fa = f(a)
    fb = f(b);

    if (fa * fb > 0):
        ier = 1
        astar = a

        return [astar, ier]

    #   verify end points are not a root
    if (fa == 0):
        astar = a
        ier = 0

        return [astar, ier]

    if (fb == 0):
        astar = b
        ier = 0

        return [astar, ier]

    count = 0
    d = 0.5 * (a + b)
    while (abs(d - a) > tol):
        fd = f(d)
        print("d = ",d,", n = ", count)
        if (fd == 0):
            astar = d
            ier = 0
            print(astar)
            return [astar, ier]
        if (fa * fd < 0):
            b = d
        else:
            a = d
            fa = fd
        d = 0.5 * (a + b)
        count = count + 1
    #      print('abs(d-a) = ', abs(d-a))

    astar = d

    ier = 0

    return [astar, ier]


driver()
# Out:
# d =  1.5707963267948966 , n =  0
# d =  0.7853981633974483 , n =  1
# d =  1.1780972450961724 , n =  2
# d =  0.9817477042468103 , n =  3
# d =  0.8835729338221293 , n =  4
# d =  0.9326603190344698 , n =  5
# d =  0.9081166264282996 , n =  6
# d =  0.8958447801252145 , n =  7
# d =  0.889708856973672 , n =  8
# d =  0.8866408953979006 , n =  9
# d =  0.8881748761857863 , n =  10
# d =  0.8874078857918435 , n =  11
# d =  0.8877913809888149 , n =  12
# d =  0.8879831285873006 , n =  13
# d =  0.8878872547880577 , n =  14
# d =  0.8878393178884363 , n =  15
# d =  0.887863286338247 , n =  16
# d =  0.8878513021133416 , n =  17
# d =  0.8878572942257943 , n =  18
# d =  0.8878602902820206 , n =  19
# d =  0.8878617883101338 , n =  20
# d =  0.8878625373241904 , n =  21
# d =  0.8878621628171621 , n =  22
# d =  0.8878623500706763 , n =  23
# d =  0.8878622564439191 , n =  24
# d =  0.8878622096305406 , n =  25
# d =  0.8878622330372299 , n =  26
# d =  0.8878622213338853 , n =  27
# ...

# %%
# Finding the roots of the equation x-4sin(2x)-3=0 [BRUTE FORCE METHOD]

# Define g(x), where g(x) = x in FPM
def g(x):
    return (4*np.sin(2*x)-3)

# Define the fixed point algorithm (from lab example)
def fixedpt(f, x0, tol, Nmax):

    count = 0
    p=[]
    while (count < Nmax):
        p.append(float(x0))
        count = count + 1
        x1 = f(x0)
        if (abs(x1 - x0) < tol):
            xstar = x1
            ier = 0

            return [xstar, ier, p]
        x0 = x1

    xstar = x1
    ier = 1
    return [xstar, ier, p]

# Since the number of roots is known, set a limit on desired roots
Nroots = 7
roots = np.zeros((1,Nroots))

# Input parameters to the fixed point method
tol = 1e-10
tries = 1000 # Number of possible points in [a,b] to try
Nmax = 100

# Bounds for guesses
a = -1
b = 8

pot_x = np.linspace(a,b,tries) # Potential values of x within a given range
indeces = np.linspace(0,tries-1,tries) # Number of test values
indeces_roots = np.linspace(0,Nroots-1,Nroots) # Number of roots from 0 to Nroots-1
index = 0 # Found roots

print(roots)
for i in indeces:
    i = int(i)

    # Calculating the fixed point for all x in the potential x vector
    xstar = fixedpt(g, pot_x[i], tol, Nmax)

    for j in indeces_roots:
        j = int(j)
        # Making sure the found root was not already found and stored in roots (within tolerance)
        if (np.abs(xstar - roots[j]) > tol):
            roots[index] = xstar
            index +=1
# Out:
# [[0. 0. 0. 0. 0. 0. 0.]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 55
#      53 j = int(j)
#      54 # Making sure the found root was not already found and stored in roots (within tolerance)
# ---> 55 if (np.abs(xstar - roots[j]) > tol):
#      56     roots[index] = xstar
#      57     index +=1
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.

# %%
# Finding the roots of the equation x-4sin(2x)-3=0

# Define g(x), where g(x) = x in FPM
def g(x):
    return (4*np.sin(2*x)-3)

# Define the fixed point algorithm (from lab example)
def fixedpt(f, x0, tol, Nmax):

    count = 0
    p=[]
    while (count < Nmax):
        p.append(float(x0))
        count = count + 1
        x1 = f(x0)
        if (abs(x1 - x0) < tol):
            xstar = x1
            ier = 0

            return [xstar, ier, p]
        x0 = x1

    xstar = x1
    ier = 1
    return [xstar, ier, p]

# Since the number of roots is known, set a limit on desired roots
Nroots = 7

# Input parameters to the fixed point method
tol = 1e-10
Nmax = 1000
# Input of original guess for x0
# Use the graph to pick one that is to the left of all roots as close as possible to the first root
x0 = -1

dx = 0.5

[xstar, ier, p] = fixedpt(g, x0, tol, Nmax)
print(xstar)
#def multiple_roots(x0,dx,tol,Nroots,g,fixedpt,Nmax):
    # x0 = the leftmost guess for the roots
    # dx = the guess step length to iterate through all the possible roots. Decrease value if roots may be extremely close together
    # tol = tolerance of the fixed pt method
    # Nroots = Number of roots, found from graphing the function
    # g = fixed point function
    # fixedpt = function to complete the fixed point method
    # Nmax = max number of iterations of the function (helps determine if dx is sized appropriately), also a limit on the iterations of 
    #roots = np.empty(Nroots)
    #roots_found = 0

    # Finding the first root
    #roots[roots_found] = fixedpt(f, x0, tol, Nmax)
    # Iterate through the process over and over to find the roots. 
    #while roots_found<Nroots:
        #while ier == 1:
# Out:
# 0.7491338830477678
