# %% [markdown]
# ### Kepler's Equations and Position Estimation

# %% [markdown]
# #### Using the Orbit object to convert position and velocity to keplerian elements

# %%
from math_tools import *
from graphing_utils import Graph
from orbit_package import Orbit

gr = Graph()
orb = Orbit()

# Values of r,v and mu to get elements for
mu = 4e5 # km^3/s^2
r0_vec = np.array([6e3,6e3,6e3]) # km
v0_vec = np.array([-5,5,0]) #km/s

# Finding kep elements
elements = orb.orbital_elements(r0_vec,v0_vec,mu)
orb.print_elements(elements)
# Out:
# SMA: 14825.777163600662
# RAAN: 5.497787143782138
# Arg Periapsis: 1.5707963267948966
# Inclination: 0.6154797086703874
# Orbit Period: 17933.954973952295
# Mean Anomaly: 0.0
# Eccentric Anomaly: 0.0
# Mean Motion: 0.00035035134839501015
# True Anomaly: 1.4901161193847656e-08
# Orbit Type: prograde

# %% [markdown]
# ### Creating an Ephemeris object for the orbit

# %%
dt = np.linspace(-2*7200,2*7200,2000)
eph = orb.create_propagated_ephemeris(r0_vec,v0_vec,mu,dt)

# %% [markdown]
# ##### Using built in Ephemeris functions to extract r,c,t and elements

# %%
all_r = eph.all_r()
all_v = eph.all_v()
all_t = eph.all_t()
all_ele = eph.all_ele()
print(all_t)
# Out:
# [datetime.datetime(2025, 9, 3, 12, 25, 30, 68559, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 25, 44, 475763, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 25, 58, 882966, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 26, 13, 290170, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 26, 27, 697373, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 26, 42, 104577, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 26, 56, 511781, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 27, 10, 918984, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 27, 25, 326188, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 27, 39, 733391, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 27, 54, 140595, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 28, 8, 547799, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 28, 22, 955002, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 28, 37, 362206, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 28, 51, 769409, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 29, 6, 176613, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 29, 20, 583817, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 29, 34, 991020, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 29, 49, 398224, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 30, 3, 805427, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 30, 18, 212631, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 30, 32, 619835, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 30, 47, 27038, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 31, 1, 434242, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 31, 15, 841445, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 31, 30, 248649, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 31, 44, 655853, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 31, 59, 63056, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 32, 13, 470260, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 32, 27, 877463, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 32, 42, 284667, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 32, 56, 691871, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 33, 11, 99074, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 33, 25, 506278, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 33, 39, 913481, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 33, 54, 320685, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 34, 8, 727889, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 34, 23, 135092, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 34, 37, 542296, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 34, 51, 949499, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 35, 6, 356703, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 35, 20, 763907, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 35, 35, 171110, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 35, 49, 578314, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 36, 3, 985517, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 36, 18, 392721, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 36, 32, 799925, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 36, 47, 207128, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 37, 1, 614332, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 9, 3, 12, 37, 16,  ...

# %% [markdown]
# #### Plotting the results of the ephemeris

# %%
from graphing_utils import Graph

gr = Graph()
gr.plot_eph_pos_vector(eph,'line')
nu = eph.all_nu()
gr.plot_dt_simple(dt,nu,['True Anomaly','Rad'])
gr.plot_eph_v_norm(eph)
gr.plot_eph_nu(eph)
gr.plot_eph_r_norm(eph)
